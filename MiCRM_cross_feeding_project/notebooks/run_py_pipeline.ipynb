# %%
#Imports
import os
import time
import sys
import subprocess
import pandas as pd
from multiprocessing import Pool

# %%
# Import Packages

# %%
# Getting refseq table
refseq = pd.read_csv("../data/refseq_release_201.tsv", sep='\t', index_col=[0])

# %%
# Out:
#                      bioproject     biosample         wgs_master  \
# assembly_accession
# GCF_000001215.4        PRJNA164  SAMN02803731                NaN
# GCF_000001405.39       PRJNA168           NaN                NaN
# GCF_000001635.26       PRJNA169           NaN                NaN
# GCF_000001735.4        PRJNA116  SAMN03081427                NaN
# GCF_000001895.5      PRJNA12455  SAMN02808228     AABR00000000.7
# ...                         ...           ...                ...
# GCF_903995475.1     PRJNA224116  SAMEA7110814  CAJFAE000000000.1
# GCF_903995485.1     PRJNA224116  SAMEA7110813  CAJFAD000000000.1
# GCF_903995555.1     PRJNA224116  SAMEA7175806  CAJFAG000000000.1
# GCF_904061905.1     PRJNA224116  SAMEA7198703  CAJFCI000000000.1
# GCF_904066215.1     PRJNA224116  SAMEA7233140                NaN
#
#                           refseq_category    taxid  species_taxid  \
# assembly_accession
# GCF_000001215.4          reference genome     7227           7227
# GCF_000001405.39         reference genome     9606           9606
# GCF_000001635.26         reference genome    10090          10090
# GCF_000001735.4          reference genome     3702           3702
# GCF_000001895.5     representative genome    10116          10116
# ...                                   ...      ...            ...
# GCF_903995475.1                        na   766224         766224
# GCF_903995485.1                        na   170679         170679
# GCF_903995555.1                        na      316            316
# GCF_904061905.1                        na  2762745        2762745
# GCF_904066215.1                        na  2766784        2766784
#
#                               organism_name infraspecific_name  \
# assembly_accession
# GCF_000001215.4     Drosophila melanogaster                NaN
# GCF_000001405.39               Homo sapiens                NaN
# GCF_000001635.26               Mus musculus                NaN
# GCF_000001735.4        Arabidopsis thaliana   ecotype=Columbia
# GCF_000001895.5           Rattus norvegicus       strain=mixed
# ...                                     ...                ...
# GCF_903995475.1             Vibrio jasicida                NaN
# GCF_903995485.1             Vibrio chagasii                NaN
# GCF_903995555.1        Pseudomonas stutzeri                NaN
# GCF_904061905.1      Pseudomonas sp. Wesi-4                NaN
# GCF_904066215.1     Microbacterium sp. Nx66                NaN
#
#                                     isolate version_status  ... release_type  \
# assembly_accession                                          ...
# GCF_000001215.4                         NaN         latest  ...        Major
# GCF_000001405.39                        NaN         latest  ...        Patch
# GCF_000001635.26                        NaN         latest  ...        Patch
# GCF_000001735.4                         NaN         latest  ...        Minor
# GCF_000001895.5                         NaN         latest  ...        Major
# ...                                     ...            ...  ...          ...
# GCF_903995475.1        Vibrio jasicida 20LP         latest  ...        Major
# GCF_903995485.1        Vibrio chagasii 18LP         latest  ...        Major
# GCF_903995555.1               PSEUDT2.31D-1         latest  ...        Major
# GCF_904061905.1                   CIP111764         latest  ...        Major
# GCF_904066215.1     Microbacterium sp. Nx66         latest  ...        Major
#
#                    genome_rep seq_rel_date                asm_name  \
# assembly_accession
# GCF_000001215.4          Full   2014/08/01  Release 6 plus ISO1 MT
# GCF_000001405.39         Full   2019/02/28              GRCh38.p13
# GCF_000001635.26         Full   2017/09/15               GRCm38.p6
# GCF_000001735.4          Full   2018/03/15                TAIR10.1
# GCF_000001895.5          Full   2014/07/01                Rnor_6.0
# ...                       ...          ...                     ...
# GCF_903995475.1          Full   2020/08/20           ASM90399547v1
# GCF_903995485.1          Full   2020/08/20           ASM90399548v1
# GCF_903995555.1          Full   2020/08/20                 PSEUDT2
# GCF_904061905.1          Full   2020/09/02               CIP111764
# GCF_904066215.1          Full   2020/09/02           ASM90406621v1
#
#                                                             submitter  \
# assembly_accession
# GCF_000001215.4     The FlyBase Consortium/Berkeley Drosophila Gen...
# GCF_000001405.39                          Genome Reference Consortium
# GCF_000001635.26                          Genome Reference Consortium
# GCF_000001735.4           The Arabidopsis Information Resource (TAIR)
# GCF_000001895.5                      Rat Genome Sequencing Consortium
# ...                                                               ...
# GCF_903995475.1                                               iBB-IST
# GCF_903995485.1                                               iBB-IST
# GCF_903995555.1                                                 CBMSO
# GCF_904061905.1                                      INSTITUT PASTEUR
# GCF_904066215.1                                                  GMGM
#
#                      gbrs_paired_asm paired_asm_comp  \
# assembly_accession
# GCF_000001215.4      GCA_000001215.4       identical
# GCF_000001405.39    GCA_000001405.28       different
# GCF_000001635.26     GCA_000001635.8       identical
# GCF_000001735.4      GCA_000001735.2       identical
# GCF_000001895.5      GCA_000001895.4       identical
# ...                              ...             ...
# GCF_903995475.1      GCA_903995475.1       identical
# GCF_903995485.1      GCA_903995485.1       identical
# GCF_903995555.1      GCA_903995555.1       identical
# GCF_904061905.1      GCA_904061905.1       identical
# GCF_904066215.1      GCA_904066215.1       identical
#
#                                                              ftp_path  \
# assembly_accession
# GCF_000001215.4     ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# GCF_000001405.39    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# GCF_000001635.26    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# GCF_000001735.4     ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# GCF_000001895.5     ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# ...                                                               ...
# GCF_903995475.1     ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/903...
# GCF_903995485.1     ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/903...
# GCF_903995555.1     ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/903...
# GCF_904061905.1     ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/904...
# GCF_904066215.1     ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/904...
#
#                    excluded_from_refseq relation_to_type_material
# assembly_accession
# GCF_000001215.4                     NaN                       NaN
# GCF_000001405.39                    NaN                       NaN
# GCF_000001635.26                    NaN                       NaN
# GCF_000001735.4                     NaN                       NaN
# GCF_000001895.5                     NaN                       NaN
# ...                                 ...                       ...
# GCF_903995475.1                     NaN                       NaN
# GCF_903995485.1                     NaN                       NaN
# GCF_903995555.1                     NaN                       NaN
# GCF_904061905.1                     NaN                       NaN
# GCF_904066215.1                     NaN                       NaN
#
# [210741 rows x 21 columns]
